# %% [markdown]
# ## (06MPL)Assignment - Data Visulization with MatPlotLib and Seaborn ##

# %% [markdown]
# In this assignment, you will use sample data or included datasets from Seaborn library to visualize data by creating different graphs. To complete this assignment, you goto each question and answer it in the code cell after it. You can add more code cell as necessary. Run your code after you finish the question to make sure there is no error before moving on to next question. Compare your output with the output image as reference.

# %% [markdown]
# 1. Download file MPLAssignmentTemplate.ipynb
# 1. Rename your file as MPLLastFirst.ipynb where Last is your last name and First is your first name
# 1. Complete the following 10 questions.  When completing each questoin, run your code.  You may add extra code cell for your answer
# 1. Compapre your result with the output image provided in the question
# 1. Submit your ipynb file and a screenshot of your repository showing that you have pushed the inpynb file to your repository

# %% [markdown]
# **Q01. Import MatPlotLib PyPlot module as plt and Seaborn module as sns; also include the command to make sure the image is static**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# **Q02. Given the following data, create a line chart with the following properties:**<br>
#
#       1. Chart title:'Weekly Temperature'; label for X axis:'Week Day'; label for Y axis:'Tempearue in Fahrenheit'
#       2. Add line color, line width, line style, marker, and alpha of your choice
#       3. Add legend and grid
#       4. Use output image as reference
# **Output image:** <br>
# ![q2.png](attachment:568b603b-4bf9-4ac2-9246-a6edbb5ab789.png)

# %%
week_day = ['SUN','MON','TUE','WED','THU','FRI','SAT']
high_temp = [88, 97, 95, 98, 100, 101, 93]
low_temp = [77, 80, 79, 73, 80, 81, 78]
avg_temp = [82, 88, 87, 85, 90, 91, 86]

plt.figure(figsize=(6,5))

plt.plot(week_day, high_temp, color= 'blue', linestyle= '-.', linewidth = 2, marker = '+', alpha = 0.2, label = 'High')
plt.plot(week_day, low_temp, color= 'green', linestyle= '-.', linewidth = 2, marker = '+', alpha = 0.2, label = 'Low')
plt.plot(week_day, avg_temp, color= 'red', linestyle= '-.', linewidth = 2, marker = '+', alpha = 0.2, label = 'Avg')

plt.title('Weekly Temperature')
plt.xlabel('Day of the Week')
plt.ylabel('Temperature in Fahrenheit')

plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# **Q03. Use the data below, create a stacked bar chart. Use the output image as reference**<br>
# years = range(2015,2020) <br>
# class_counts = {
#     'Face to Face':np.array([47, 50, 48, 40, 35]),
#     'Online': np.array([29, 28, 40, 45, 50]),
# }<br><br>
# **Output image:** <br>
# ![q3.png](attachment:7c066b6e-85d9-4d73-bcb8-9e50ac4d8f8c.png)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

years = range(2015, 2020)
class_counts = {'Face to Face':np.array([47,50,48,40,35]), 'Online':np.array([29,28,40,45,50]),}

plt.figure(figsize = (8,10))

plt.bar(years, class_counts['Face to Face'], label='Face to Face', color='blue')

plt.bar(years, class_counts['Online'], bottom = class_counts['Face to Face'], label = 'Online', color ='orange')


plt.text(2015, 47/2, '47', color='white')
plt.text(2016, 50/2, '50', color='white')
plt.text(2017, 48/2, '48', color='white')
plt.text(2018, 40/2, '40', color='white')
plt.text(2019, 35/2, '35', color='white')


plt.text(2015, 47 + 29/2, '29', color='black')
plt.text(2016, 50 + 28/2, '28', color='black')
plt.text(2017, 48 + 40/2, '40', color='black')
plt.text(2018, 40 + 45/2, '45', color='black')
plt.text(2019, 35 + 50/2, '50', color='black')


plt.title('Class Modality')
plt.xlabel('Years')
plt.ylabel('Number of Classes')

plt.legend()
plt.grid(True)


plt.show()

# %% [markdown]
# **Q04. Load dataset 'iris' from Seaborn and create a stacked Histogram chart to see the distribution of sepal length. Use the output image as reference.** <br><br>
# **Output image:**<br>
# ![q4.png](attachment:d172c68a-6fd0-4ac5-b642-ef2f1360ce9e.png)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

flowers_df = sns.load_dataset("iris")

setosa = flowers_df[flowers_df['species'] == 'setosa']['sepal_length']
versicolor = flowers_df[flowers_df['species'] == 'versicolor']['sepal_length']
virginica = flowers_df[flowers_df['species'] == 'virginica']['sepal_length']

plt.figure(figsize=(8,8))

plt.hist([setosa, versicolor, virginica],
         bins = 15,
         stacked = True,
         label = ['Setosa', 'Versicolor', 'Virginica'],
         color = ['blue', 'orange', 'green'])

plt.title('Distribution of Sepal length')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')

plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# **Q05. Load dataset 'tips' from Seaborn and create the bar chart (use Seaborn barplot() method) to display bill amount on each day based on gender of servers. Use the output image as reference.**<br><br>
# **Output image:** <br>
# ![q5.png](attachment:167fd23c-1170-4904-b9c8-f8838a662b88.png)

# %%
tips_df = sns.load_dataset('tips')
#print(tips_df)

plt.figure(figsize = (8,8))

sns.barplot(
    data= tips_df,
    x = 'day',
    y = 'total_bill',
    hue = 'sex',
    palette = {'Male': 'blue', 'Female': 'red'})

plt.title('Total Bill by Day and Gender')
plt.xlabel('Day')
plt.ylabel('Total Bill')

plt.show()

# %% [markdown]
# **Q06. Convert the Bar chart from Q05 to Horizontal Bar chart. Use the output image as reference.**<br><br>
# **Output image:** <br>
# ![q6.png](attachment:2615c431-ea50-4c8f-86bf-c55afdedcb30.png)

# %%
tips_df = sns.load_dataset('tips')
#print(tips_df)

plt.figure(figsize = (8,8))

sns.barplot(
    data= tips_df,
    x = 'total_bill',
    y = 'day',
    hue = 'sex',
    palette = {'Male': 'blue', 'Female': 'red'})

plt.title('Total Bill by Day and Gender')
plt.xlabel('Day')
plt.ylabel('Total Bill')

plt.show()

# %% [markdown]
# **Q07. Load tips dataset and create scatter chart(Seaborn scatterplot() method) to see the relationship between tip and bill amount using day as hue. Use the output image as reference.**<br><br>
# **Output image:** <br>
# ![q7.png](attachment:12ab643c-1430-438e-9533-b5e70fe23cab.png)

# %%
tips_df = sns.load_dataset('tips')
#print(tips_df)

plt.figure(figsize=(8,8))

sns.scatterplot(
    data = tips_df,
    x = 'tip',
    y = 'total_bill',
    hue = 'day')

plt.title('Tip vs. Total bill')

plt.legend()
plt.grid(True)

plt.show()

# %% [markdown]
# **Q08. Create a pie chart based on the data below to show class modality and its weight. Use the output image as reference.** <br>
# modality = ['Face to Face', 'Online Anytime', 'Online with Schedule'] <br>
# weight = [30, 50, 20]<br><br>
# **Output image:**<br>
# ![q8.png](attachment:d77921c3-9f9d-48b3-82d7-2506f25a7736.png)

# %%
modality = ['Face to Face', 'Online Anytime', 'Online with Schedule']
weight = [30, 50, 20]

explode = [0.1, 0, 0]

plt.figure(figsize=(6,6))

plt.pie(
    weight,
    labels = modality,
    autopct = '%.1f%%',
    explode = explode,
    shadow = True,
    startangle = 145,
    colors = ['yellow', 'orange', 'lightblue'])

plt.title('Class Modality for Fall 2024')
plt.show()

# %% [markdown]
# **Q09. Save the the pie chart from Q7 to a pdf file named pie.pdf and save it next to this assignment file**

# %%
modality = ['Face to Face', 'Online Anytime', 'Online with Schedule']
weight = [30, 50, 20]

explode = [0.1, 0, 0]

plt.figure(figsize=(6,6))

plt.pie(
    weight,
    labels = modality,
    autopct = '%.1f%%',
    explode = explode,
    shadow = True,
    startangle = 145,
    colors = ['yellow', 'orange', 'lightblue'])

plt.title('Class Modality for Fall 2024')

plt.savefig("pie.pdf")

plt.show()

# %% [markdown]
# **Q10. Use Seaborn pair plot to automatically plot several different charts for pairs of features within the 'tips' dataset. Use your choice of hue. Use the output image as reference.**<br><br>
# **Output image:**<br>
# ![q10.png](attachment:c5fdbfc7-9077-40a2-a6eb-636da1833933.png)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

tips_df = sns.load_dataset("tips")

sns.pairplot(data = tips_df, hue = 'day')

plt.show()
